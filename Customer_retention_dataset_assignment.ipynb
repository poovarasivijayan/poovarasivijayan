# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#importing our dataset

sheet = pd.read_excel(r"C:\Users\poovi\Downloads\Customer_retention_dataset-\Customer_retention_dataset\customer_retention_dataset.xlsx",sheet_name=None)

# %%
sheet.keys()
# Out:
# dict_keys(['datasheet', 'codedsheet'])

# %%
df = sheet['datasheet']
df1=sheet['codedsheet']

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# I am changing the names of column for easy understanding

# %%
col = ['Gender','Age','City','Pincode','How long shopping online','No of Purchase','Access Internet','Device','ScreenSize','OS','Browser','Channel','How you reach online store','Time for exploring','Payment Option','Abonded purchase','Abond cart/bag','Content Understanding','Product Comparision','Information of seller/product','Information on Product','Ease of Navigation','Loading Speed','User Friendly Interference','Payment Method','Transaction Time','Empathy','Privacy','Responsive','Discounts/benefits','Enjoyment','Convienent&Flexible','Return/Replacement','Gaining access to Loyality Program','Quality Information','Satisfication','Net Benefits','Trust','Wide Variety of Products','Product Information','Monetary Savings','Patronizing','Adventure','Social Status','Gratification Shopping','Certain roles','Value for money','From the following','Ease to use','Visual Appealing','Product on offer','Description','Speed od website/application','Reliablity','Quickness','Payment Options','Speed of delivery','Privacy of customer','Security','Trustworthiness','Online assistance','Time for Log in','Graphics/Photos','Declaration of price','Loading time','Limited mode of payment','Longer Delivery period','Change in website/design','Frequent distruption','How efficient','Recommend']

# %%
df.columns = [x.upper() for x in col]

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'CITY', 'PINCODE', 'HOW LONG SHOPPING ONLINE',
#        'NO OF PURCHASE', 'ACCESS INTERNET', 'DEVICE', 'SCREENSIZE', 'OS',
#        'BROWSER', 'CHANNEL', 'HOW YOU REACH ONLINE STORE',
#        'TIME FOR EXPLORING', 'PAYMENT OPTION', 'ABONDED PURCHASE',
#        'ABOND CART/BAG', 'CONTENT UNDERSTANDING', 'PRODUCT COMPARISION',
#        'INFORMATION OF SELLER/PRODUCT', 'INFORMATION ON PRODUCT',
#        'EASE OF NAVIGATION', 'LOADING SPEED', 'USER FRIENDLY INTERFERENCE',
#        'PAYMENT METHOD', 'TRANSACTION TIME', 'EMPATHY', 'PRIVACY',
#        'RESPONSIVE', 'DISCOUNTS/BENEFITS', 'ENJOYMENT', 'CONVIENENT&FLEXIBLE',
#        'RETURN/REPLACEMENT', 'GAINING ACCESS TO LOYALITY PROGRAM',
#        'QUALITY INFORMATION', 'SATISFICATION', 'NET BENEFITS', 'TRUST',
#        'WIDE VARIETY OF PRODUCTS', 'PRODUCT INFORMATION', 'MONETARY SAVINGS',
#        'PATRONIZING', 'ADVENTURE', 'SOCIAL STATUS', 'GRATIFICATION SHOPPING',
# ...

# %%
df.head(5)
# Out:
#    GENDER          AGE           CITY  PINCODE HOW LONG SHOPPING ONLINE  \
# 0    Male  31-40 years          Delhi   110009            Above 4 years
# 1  Female  21-30 years          Delhi   110030            Above 4 years
# 2  Female  21-30 years  Greater Noida   201308                3-4 years
# 3    Male  21-30 years        Karnal    132001                3-4 years
# 4  Female  21-30 years     Bangalore    530068                2-3 years
#
#        NO OF PURCHASE  ACCESS INTERNET      DEVICE  SCREENSIZE  \
# 0         31-40 times          Dial-up     Desktop      Others
# 1  41 times and above            Wi-Fi  Smartphone  4.7 inches
# 2  41 times and above  Mobile Internet  Smartphone  5.5 inches
# 3  Less than 10 times  Mobile Internet  Smartphone  5.5 inches
# 4         11-20 times            Wi-Fi  Smartphone  4.7 inches
#
#                       OS  ...          TIME FOR LOG IN  \
# 0  Window/windows Mobile  ...                Amazon.in
# ...

# %% [markdown]
# Now we will check for null values in dataset

# %%
pd.set_option('display.max_rows',None)

# %%
df.isna().sum()
# Out:
# GENDER                                0
# AGE                                   0
# CITY                                  0
# PINCODE                               0
# HOW LONG SHOPPING ONLINE              0
# NO OF PURCHASE                        0
# ACCESS INTERNET                       0
# DEVICE                                0
# SCREENSIZE                            0
# OS                                    0
# BROWSER                               0
# CHANNEL                               0
# HOW YOU REACH ONLINE STORE            0
# TIME FOR EXPLORING                    0
# PAYMENT OPTION                        0
# ABONDED PURCHASE                      0
# ABOND CART/BAG                        0
# CONTENT UNDERSTANDING                 0
# PRODUCT COMPARISION                   0
# INFORMATION OF SELLER/PRODUCT         0
# INFORMATION ON PRODUCT                0
# EASE OF NAVIGATION                    0
# LOADING SPEED                         0
# ...

# %% [markdown]
# No null values in our data set

# %% [markdown]
# # Univariant Analysis

# %%
for i in df.columns:
    sns.countplot(df[i])
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Key Observations:

# %% [markdown]
# 1. We can see that female online buyers are more than male and mostly in the age group of 21-30 & 31-40 years.
#
# 2. Delhi has witnessed highest online shopping compared to other cities.
#
# 3. Many are doing online shopping for more than 4 years with less than 10 times thae number of purchase is done.
#
# 4. Mostly internet is accessed through mobile data in smartphones and all type of screen types are used.
#
# 5. Windows is used in most cases followes by android devices and Google browser is most frequently used search engine.
#
# 6. Many are reaching online stores via search engine and applications followed by direct url, and exploring of products is done in less than 15 minutes.
#
# 7. Online payment is done via debit/credit cards compared to other platforms.
#
# 8. Sometimes abonding products from cart happens due to other better alternatives.

# %%
customer_column   = df[['GENDER', 'AGE', 'CITY', 'PINCODE', 'HOW LONG SHOPPING ONLINE',
       'NO OF PURCHASE', 'ACCESS INTERNET', 'DEVICE', 'SCREENSIZE', 'OS',
       'BROWSER', 'CHANNEL', 'HOW YOU REACH ONLINE STORE',
       'TIME FOR EXPLORING', 'PAYMENT OPTION', 'ABONDED PURCHASE',
       'ABOND CART/BAG']]

#options are given from 1 to 5 to choose
ecommerce_column = df[['CONTENT UNDERSTANDING', 'PRODUCT COMPARISION',
       'INFORMATION OF SELLER/PRODUCT', 'INFORMATION ON PRODUCT',
       'EASE OF NAVIGATION', 'LOADING SPEED', 'USER FRIENDLY INTERFERENCE',
       'PAYMENT METHOD', 'TRANSACTION TIME', 'EMPATHY', 'PRIVACY',
       'RESPONSIVE', 'DISCOUNTS/BENEFITS', 'ENJOYMENT', 'CONVIENENT&FLEXIBLE',
       'RETURN/REPLACEMENT', 'GAINING ACCESS TO LOYALITY PROGRAM',
       'QUALITY INFORMATION', 'SATISFICATION', 'NET BENEFITS', 'TRUST',
       'WIDE VARIETY OF PRODUCTS', 'PRODUCT INFORMATION', 'MONETARY SAVINGS',
       'PATRONIZING', 'ADVENTURE', 'SOCIAL STATUS', 'GRATIFICATION SHOPPING',
       'CERTAIN ROLES']]

#application which is used
websites_column   = df[['FROM THE FOLLOWING', 'EASE TO USE',
       'VISUAL APPEALING', 'PRODUCT ON OFFER', 'DESCRIPTION',
       'SPEED OD WEBSITE/APPLICATION', 'RELIABLITY', 'QUICKNESS',
       'PAYMENT OPTIONS', 'SPEED OF DELIVERY', 'PRIVACY OF CUSTOMER',
       'SECURITY', 'TRUSTWORTHINESS', 'ONLINE ASSISTANCE', 'TIME FOR LOG IN',
       'GRAPHICS/PHOTOS', 'DECLARATION OF PRICE', 'LOADING TIME',
       'LIMITED MODE OF PAYMENT', 'LONGER DELIVERY PERIOD',
       'CHANGE IN WEBSITE/DESIGN', 'FREQUENT DISTRUPTION', 'HOW EFFICIENT',
       'RECOMMEND']]

# %%
collist = customer_column.columns.values

for i in range(0,len(collist)):
    plt.subplot(6,6)
    df([collist[i]].hist())
    plt.title("[collist[i]]")
    plt.ylabel("count")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10232/2755584427.py in <module>
#       2
#       3 for i in range(0,len(collist)):
# ----> 4     plt.subplot(6,6)
#       5     df([collist[i]].hist())
#       6     plt.title("[collist[i]]")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     655                 i = j = num
#     656         else:
# --> 657             raise TypeError(f"subplot() takes 1 or 3 positional arguments but "
#     658                             f"{len(args)} were given")
#     659
#
# ...
